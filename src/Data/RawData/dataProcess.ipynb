# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('albums.csv')
len(df)
# Out:
# 2300

# %%
df_2022 = df[df['year'] == 2022]
df_2021 = df[df['year'] == 2021]
df_2020 = df[df['year'] == 2020]
df_2019 = df[df['year'] == 2019]
df_2018 = df[df['year'] == 2018]
df_2017 = df[df['year'] == 2017]
df_2016 = df[df['year'] == 2016]
df_2015 = df[df['year'] == 2015]
df_2014 = df[df['year'] == 2014]
df_2013 = df[df['year'] == 2013]
df_2012 = df[df['year'] == 2012]
df_2011 = df[df['year'] == 2011]
df_2010 = df[df['year'] == 2010]
df_2009 = df[df['year'] == 2009]
df_2008 = df[df['year'] == 2008]
df_2007 = df[df['year'] == 2007]
df_2006 = df[df['year'] == 2006]
df_2005 = df[df['year'] == 2005]
df_2004 = df[df['year'] == 2004]
df_2003 = df[df['year'] == 2003]
df_2002 = df[df['year'] == 2002]
df_2001 = df[df['year'] == 2001]
df_2000 = df[df['year'] == 2000]

# %%
metal = []
rock = []
folk = []
pop = []
hip_hop =[]
jazz =[]
electronic = []
rnb = []
ambient = []
classical = []
others = []

# %%
def typeFilteredFunction(year,df,genre):
    for index,i in enumerate(df[genre]):
        if 'Rock' in i:
             rock.append([year,index,i])
        elif 'Hardcore' in i:
             rock.append([year,index,i])
        elif 'Screamo' in i:
             rock.append([year,index,i])
        elif 'Emo' in i:
             rock.append([year,index,i])
        elif 'Punk' in i:
             rock.append([year,index,i])
        elif 'Shoegaze' in i:
             rock.append([year,index,i])
        elif 'Zeuhl' in i:
             rock.append([year,index,i])
        elif 'Avant-Prog' in i:
             rock.append([year,index,i])
        elif 'Neo-Psychedelia' in i:
             rock.append([year,index,i])
        elif 'Riot Grrrl' in i:
             rock.append([year,index,i])
        elif 'Symphonic Prog' in i:
             rock.append([year,index,i])
        elif 'Slowcore' in i:
             rock.append([year,index,i])
        elif 'Neocrust' in i:
             rock.append([year,index,i])
        elif 'UK Garage' in i:
             rock.append([year,index,i])
        elif 'D-Beat' in i:
             rock.append([year,index,i])
        elif 'rock' in i:
             rock.append([year,index,i])
        elif 'AOR' in i:
             rock.append([year,index,i])
        elif 'Yakousei' in i:
             rock.append([year,index,i])
        elif 'Tishoumaren' in i:
             rock.append([year,index,i])
        elif 'Heavy Psych' in i:
             rock.append([year,index,i])
        elif 'Queercore' in i:
             rock.append([year,index,i])
        elif 'Stenchcore' in i:
             rock.append([year,index,i])
        elif 'Swancore' in i:
             rock.append([year,index,i])
        elif 'New Wave' in i:
             rock.append([year,index,i])
        elif 'Blackgaze' in i:
             metal.append([year,index,i])
        elif "Metal" in i:
            metal.append([year,index,i])
        elif "Grindcore" in i:
            metal.append([year,index,i])
        elif "grind" in i:
            metal.append([year,index,i])
        elif "Deathcore" in i:
            metal.append([year,index,i])
        elif "Neo-Prog" in i:
            metal.append([year,index,i])
        elif "Mathcore" in i:
            metal.append([year,index,i])
        elif "Djent" in i:
            metal.append([year,index,i])
        elif "Powerviolence" in i:
            metal.append([year,index,i])
        elif "Folk" in i:
            folk.append([year,index,i])
        elif "Singer-Songwriter" in i:
            folk.append([year,index,i])
        elif "Country" in i:
            folk.append([year,index,i])
        elif "Americana" in i:
            folk.append([year,index,i])
        elif "American Primitivism" in i:
            folk.append([year,index,i])
        elif "Celtic" in i:
            folk.append([year,index,i])
        elif "folk" in i:
            folk.append([year,index,i])
        elif "blues" in i:
            folk.append([year,index,i])
        elif "Blues" in i:
            folk.append([year,index,i])
        elif "Acoustic" in i:
            folk.append([year,index,i])
        elif "Pop" in i:
            pop.append([year,index,i])
        elif "Bubblegum Bass" in i:
            pop.append([year,index,i])
        elif "pop" in i:
            pop.append([year,index,i])
        elif "Akishibu-kei" in i:
            pop.append([year,index,i])
        elif "Shibuya-kei" in i:
            pop.append([year,index,i])
        elif "Alternative Dance" in i:
            pop.append([year,index,i])
        elif "Indietronica" in i:
            pop.append([year,index,i])
        elif "Plunderphonics" in i:
            pop.append([year,index,i])
        elif "Minimal Wave" in i:
            pop.append([year,index,i])
        elif "Rap" in i:
            hip_hop.append([year,index,i])
        elif "Trap" in i:
            hip_hop.append([year,index,i])
        elif "Drumless" in i:
            hip_hop.append([year,index,i])
        elif 'Boom Bap' in i:
            hip_hop.append([year,index,i])
        elif "Hop" in i:
            hip_hop.append([year,index,i])
        elif "Horrorcore" in i:
            hip_hop.append([year,index,i])
        elif "Grime" in i:
            hip_hop.append([year,index,i])
        elif "Dirty South" in i:
            hip_hop.append([year,index,i])
        elif "Wonky" in i:
            hip_hop.append([year,index,i])
        elif "Deconstructed Club" in i:
            hip_hop.append([year,index,i])
        elif "Miami Bass" in i:
            hip_hop.append([year,index,i])
        elif "UK Bass" in i:
            hip_hop.append([year,index,i])
        elif "Jazz" in (i):
            jazz.append([year,index,i])
        elif "Wolof Music" in (i):
            jazz.append([year,index,i])
        elif "Liquid Drum and Bass" in (i):
            jazz.append([year,index,i])
        elif "Post-Bop" in (i):
            jazz.append([year,index,i])
        elif "Progressive Bluegrass" in (i):
            jazz.append([year,index,i])
        elif "Electro" in i:
            electronic.append([year,index,i])
        elif "Future Bass" in i:
            electronic.append([year,index,i])
        elif "Vaporwave" in i:
            electronic.append([year,index,i])
        elif "House" in i:
            electronic.append([year,index,i])
        elif "Minimal Drum and Bass" in i:
            electronic.append([year,index,i])
        elif "Industrial" in i:
            electronic.append([year,index,i])
        elif "Nu-Disco" in i:
            electronic.append([year,index,i])
        elif "Neurofunk" in i:
            electronic.append([year,index,i])
        elif "Chillwave" in i:
            electronic.append([year,index,i])
        elif "Experimental" in i:
            electronic.append([year,index,i])
        elif "IDM" in i:
            electronic.append([year,index,i])
        elif "Dubstep" in i:
            electronic.append([year,index,i])
        elif "House" in i:
            electronic.append([year,index,i])
        elif "Techno" in i:
            electronic.append([year,index,i])
        elif "EAI" in i:
            electronic.append([year,index,i])
        elif "Disco" in i:
            electronic.append([year,index,i])
        elif "Glitch" in i:
            electronic.append([year,index,i])
        elif "house" in i:
            electronic.append([year,index,i])
        elif "Breakbeat" in i:
            electronic.append([year,index,i])
        elif "R&B" in i:
            rnb.append([year,index,i])
        elif "Soul" in i:
            rnb.append([year,index,i])
        elif "MPB" in i:
            rnb.append([year,index,i])
        elif "Funk" in i:
            rnb.append([year,index,i])
        elif "Ambient" in i:
            ambient.append([year,index,i])
        elif "Drone" in i:
            ambient.append([year,index,i])
        elif "Musique concrète" in i:
            ambient.append([year,index,i])
        elif "Future Garage" in i:
            ambient.append([year,index,i])
        elif "Hi-Tech Psytrance" in i:
            ambient.append([year,index,i])
        elif "Darkwave" in i:
            ambient.append([year,index,i])
        elif "Noise" in i:
            ambient.append([year,index,i])
        elif "Tape Music" in i:
            ambient.append([year,index,i])
        elif "Collage" in i:
            ambient.append([year,index,i])
        elif "Flashcore" in i:
            ambient.append([year,index,i])
        elif "Classical" in i:
            classical.append([year,index,i])
        elif "Baroque Music" in i:
            classical.append([year,index,i])
        elif "Stochastic Music" in i:
            classical.append([year,index,i])
        elif "Neoclassical" in i:
            classical.append([year,index,i])
        elif "Chamber Music" in i:
            classical.append([year,index,i])
        elif "Romanticism" in i:
            classical.append([year,index,i])
        elif "Renaissance Music" in i:
            classical.append([year,index,i])
        elif "Spectralism" in i:
            classical.append([year,index,i])
        elif "Breakcore" in i:
            classical.append([year,index,i])
        elif "Choral" in i:
            classical.append([year,index,i])
        elif "Tone Poem" in i:
            classical.append([year,index,i])
        elif "Minimalism" in i:
            classical.append([year,index,i])
        elif "Field Recordings" in i:
            classical.append([year,index,i])
        elif "Orchestral" in i:
            classical.append([year,index,i])
        elif "Romantic" in i:
            classical.append([year,index,i])
        else:
            others.append([year,index,i])

# %%
typeFilteredFunction(2022,df_2022, "genre_1")
typeFilteredFunction(2021,df_2021, "genre_1")
typeFilteredFunction(2020,df_2020, "genre_1")
typeFilteredFunction(2019,df_2019, "genre_1")
typeFilteredFunction(2018,df_2018, "genre_1")
typeFilteredFunction(2017,df_2017, "genre_1")
typeFilteredFunction(2016,df_2016, "genre_1")
typeFilteredFunction(2015,df_2015, "genre_1")
typeFilteredFunction(2014,df_2014, "genre_1")
typeFilteredFunction(2013,df_2013, "genre_1")
typeFilteredFunction(2012,df_2012, "genre_1")
typeFilteredFunction(2011,df_2011, "genre_1")
typeFilteredFunction(2010,df_2010, "genre_1")
typeFilteredFunction(2009,df_2009, "genre_1")
typeFilteredFunction(2008,df_2008, "genre_1")
typeFilteredFunction(2007,df_2007, "genre_1")
typeFilteredFunction(2006,df_2006, "genre_1")
typeFilteredFunction(2005,df_2005, "genre_1")
typeFilteredFunction(2004,df_2004, "genre_1")
typeFilteredFunction(2003,df_2003, "genre_1")
typeFilteredFunction(2002,df_2002, "genre_1")
typeFilteredFunction(2001,df_2001, "genre_1")
typeFilteredFunction(2000,df_2000, "genre_1")

# %%
counts =[len(metal),len(rock),len(pop),len(folk),len(hip_hop),len(jazz),len(electronic),len(ambient),len(rnb),len(classical)]
counts
# Out:
# [651, 568, 233, 204, 258, 57, 107, 78, 51, 54]

# %%
df = pd.read_csv('../GenrePageData/genreTypes.csv')
df.head(10)
# Out:
#    index  year  genre                  subgenre
# 0      0  2022  Metal         Avant-Garde Metal
# 1      1  2022  Metal                 Grindcore
# 2      2  2022  Metal               Black Metal
# 3      3  2022  Metal                 Blackgaze
# 4      4  2022  Metal              Thrash Metal
# 5      5  2022  Metal               Death Metal
# 6      6  2022  Metal  Atmospheric Sludge Metal
# 7      7  2022  Metal     Dissonant Death Metal
# 8      8  2022  Metal         Progressive Metal
# 9      9  2022  Metal   Atmospheric Black Metal

# %%
subgenre_count = df.groupby(['genre','subgenre'])['subgenre'].count()
subgenre_count
# Out:
# genre    subgenre
# Ambient  Ambient           30
#          Dark Ambient       4
#          Darkwave           3
#          Drone             13
#          Epic Collage       1
#                            ..
# Rock     Symphonic Prog    11
#          Tishoumaren        1
#          UK Garage          1
#          Yakousei           1
#          Zeuhl              4
# Name: subgenre, Length: 307, dtype: int64

# %%
subgenre_count.to_csv("../GenrePageData/ForceLayoutData/subgenre.csv")
